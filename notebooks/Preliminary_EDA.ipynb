# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls gdrive
# Out:
# 'My Drive'

# %%
# Libraries Needed
import json as json
import pandas as pd

# %%
#open json file
data = []
# gdrive/My Drive/Twitter/tweets_sample.json
with open("gdrive/My Drive/Twitter/tweets_sample.json") as td:
    for line in td:
        data.append(json.loads(line))

# %%
data[1]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue May 29 03:32:39 +0000 2018',
#  'entities': {'hashtags': [],
#   'media': [{'display_url': 'pic.twitter.com/wdJJPqUJ6C',
#     'expanded_url': 'https://twitter.com/LaGaceta_me/status/1001299608214138880/photo/1',
#     'id': 1001299606586589184,
#     'id_str': '1001299606586589184',
#     'indices': [99, 122],
#     'media_url': 'http://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#     'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 599},
#      'medium': {'h': 600, 'resize': 'fit', 'w': 599},
#      'small': {'h': 600, 'resize': 'fit', 'w': 599},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1001299608214138880,
#     'source_status_id_str': '1001299608214138880',
#     'source_user_id': 724599156,
#     'source_user_id_str': '724599156',
#     'type': 'photo',
#     'url': 'https://t.co/wdJJPqUJ6C'}],
#   'symbols': [],
#   'urls': [{'display_url': 'ow.ly/5agI30kdFuH',
#     'expanded_url': 'http://ow.ly/5agI30kdFuH',
#     'indices': [75, 98],
#     'url': 'https://t.co/e2fRdI0jYx'}],
#   'user_mentions': [{'id': 724599156,
#     'id_str': '724599156',
#     'indices': [3, 15],
#     'name': 'LaGaceta.me',
#     'screen_name': 'LaGaceta_me'}]},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/wdJJPqUJ6C',
#     'expanded_url': 'https://twitter.com/LaGaceta_me/status/1001299608214138880/photo/1',
#     'id': 1001299606586589184,
#     'id_str': '1001299606586589184',
#     'indices': [99, 122],
#     'media_url': 'http://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#     'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 599},
#      'medium': {'h': 600, 'resize': 'fit', 'w': 599},
#      'small': {'h': 600, 'resize': 'fit', 'w': 599},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1001299608214138880,
#     'source_status_id_str': '1001299608214138880',
#     'source_user_id': 724599156,
#     'source_user_id_str': '724599156',
#     'type': 'photo',
#     'url': 'https://t.co/wdJJPqUJ6C'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1001305290741092353,
#  'id_str': '1001305290741092353',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'es',
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 1,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Tue May 29 03:10:04 +0000 2018',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/wdJJPqUJ6C',
#      'expanded_url': 'https://twitter.com/LaGaceta_me/status/1001299608214138880/photo/1',
#      'id': 1001299606586589184,
#      'id_str': '1001299606586589184',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#      'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 600, 'resize': 'fit', 'w': 599},
#       'small': {'h': 600, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/wdJJPqUJ6C'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ow.ly/5agI30kdFuH',
#      'expanded_url': 'http://ow.ly/5agI30kdFuH',
#      'indices': [58, 81],
#      'url': 'https://t.co/e2fRdI0jYx'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/wdJJPqUJ6C',
#      'expanded_url': 'https://twitter.com/LaGaceta_me/status/1001299608214138880/photo/1',
#      'id': 1001299606586589184,
#      'id_str': '1001299606586589184',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DeVUr-RVAAAGhF8.jpg',
#      'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 599},
#       'medium': {'h': 600, 'resize': 'fit', 'w': 599},
#       'small': {'h': 600, 'resize': 'fit', 'w': 599},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/wdJJPqUJ6C'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1001299608214138880,
#   'id_str': '1001299608214138880',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'Hacen pasar a un actor porno por un científico de Harvard https://t.co/e2fRdI0jYx https://t.co/wdJJPqUJ6C',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jul 29 20:38:24 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#LaGaceta.me',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'lagaceta.me',
#        'expanded_url': 'http://www.lagaceta.me',
#        'indices': [0, 23],
#        'url': 'https://t.co/Ze2vjw7Btf'}]}},
#    'favourites_count': 6631,
#    'follow_request_sent': None,
#    'followers_count': 25875,
#    'following': None,
#    'friends_count': 7532,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 724599156,
#    'id_str': '724599156',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 54,
#    'location': 'Sinaloa, México',
#    'name': 'LaGaceta.me',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/724599156/1524529459',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/968271814886436864/tQ_3-cBy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968271814886436864/tQ_3-cBy_normal.jpg',
#    'profile_link_color': '9B0000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'LaGaceta_me',
#    'statuses_count': 45508,
#    'time_zone': None,
#    'translator_type': 'regular',
#    'url': 'https://t.co/Ze2vjw7Btf',
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @LaGaceta_me: Hacen pasar a un actor porno por un científico de Harvard https://t.co/e2fRdI0jYx https://t.co/wdJJPqUJ6C',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Sep 18 03:03:44 +0000 2012',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'Instagram.com/rich.i.cerda',
#       'expanded_url': 'http://Instagram.com/rich.i.cerda',
#       'indices': [0, 23],
#       'url': 'https://t.co/kyLK08O6sY'}]}},
#   'favourites_count': 5481,
#   'follow_request_sent': None,
#   'followers_count': 327,
#   'following': None,
#   'friends_count': 186,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 830262776,
#   'id_str': '830262776',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'es',
#   'listed_count': 2,
#   'location': '',
#   'name': 'Richard™',
#   'notifications': None,
#   'profile_background_color': 'BABABA',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/556565983184158721/PqJyVi-K.jpeg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/556565983184158721/PqJyVi-K.jpeg',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830262776/1527044670',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/928102218523222017/m8sLw86z_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928102218523222017/m8sLw86z_normal.jpg',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'RdeCerda',
#   'statuses_count': 9787,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/kyLK08O6sY',
#   'utc_offset': None,
#   'verified': False}}
